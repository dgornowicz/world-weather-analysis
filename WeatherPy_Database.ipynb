# %%
#import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1450)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1450)
lat_lngs = zip(lats, lngs)

# add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# create a list for holding the cities
cities = []
# identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # if the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# print the city count to confirm sufficient count
len(cities)
# Out:
# 592

# %%
# create an empty list to hold the weather data
city_data = []

# print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# create counters
record_count = 1
set_count = 1

# define url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# loop through all the cities in our list
for i, city in enumerate(cities):

    # group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# run an API request for each of the cities
    try:
        # parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# if an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port lincoln
# Processing Record 2 of Set 1 | pangnirtung
# Processing Record 3 of Set 1 | tessalit
# Processing Record 4 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | chunoyar
# Processing Record 7 of Set 1 | kodiak
# Processing Record 8 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 1 | severo-kurilsk
# Processing Record 10 of Set 1 | podosinovets
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | grand gaube
# Processing Record 13 of Set 1 | poum
# Processing Record 14 of Set 1 | kaitangata
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | amahai
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | saldanha
# Processing Record 19 of Set 1 | brumadinho
# Processing Record 20 of Set 1 | pevek
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | hualmay
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | dingle
# Processing Record 28 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 29 of Set 1 | mahebourg
# Processing Record 30 of Set 1 | varzea grande
# Processing Record 31 of Set 1 | college
# Processing Record 32 of Set 1 | hilo
# Processing Record 33 of Set 1 | plettenberg bay
# Processing Record 34 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | longyearbyen
# Processing Record 37 of Set 1 | sonoita
# Processing Record 38 of Set 1 | yei
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | canitas
# City not found. Skipping...
# Processing Record 41 of Set 1 | ponta do sol
# Processing Record 42 of Set 1 | birao
# Processing Record 43 of Set 1 | kokopo
# Processing Record 44 of Set 1 | saskylakh
# Processing Record 45 of Set 1 | basqal
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | sur
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | pozo colorado
# Processing Record 1 of Set 2 | alofi
# Processing Record 2 of Set 2 | nome
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | itigi
# Processing Record 5 of Set 2 | yichang
# Processing Record 6 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | erzin
# Processing Record 9 of Set 2 | belaya gora
# Processing Record 10 of Set 2 | merrill
# Processing Record 11 of Set 2 | junin
# Processing Record 12 of Set 2 | giyon
# Processing Record 13 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 14 of Set 2 | biak
# Processing Record 15 of Set 2 | macau
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | khasan
# Processing Record 20 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | melita
# Processing Record 24 of Set 2 | carnarvon
# Processing Record 25 of Set 2 | port-gentil
# Processing Record 26 of Set 2 | qaanaaq
# Processing Record 27 of Set 2 | kysyl-syr
# Processing Record 28 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 2 | naze
# Processing Record 31 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 32 of Set 2 | san jeronimo
# Processing Record 33 of Set 2 | tomatlan
# Processing Record 34 of Set 2 | nuuk
# Processing Record 35 of Set 2 | bredasdorp
# Processing Record 36 of Set 2 | kisanga
# Processing Record 37 of Set 2 | jamestown
# Processing Record 38 of Set 2 | lasa
# Processing Record 39 of Set 2 | delmiro gouveia
# Processing Record 40 of Set 2 | provideniya
# Processing Record 41 of Set 2 | umm kaddadah
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | margate
# Processing Record 44 of Set 2 | bathsheba
# Processing Record 45 of Set 2 | pangai
# Processing Record 46 of Set 2 | kodino
# Processing Record 47 of Set 2 | hailey
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | benalla
# Processing Record 50 of Set 2 | pisco
# Processing Record 1 of Set 3 | port elizabeth
# Processing Record 2 of Set 3 | khatanga
# Processing Record 3 of Set 3 | avera
# Processing Record 4 of Set 3 | faanui
# Processing Record 5 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 3 | asfi
# Processing Record 7 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 3 | lethem
# Processing Record 9 of Set 3 | thompson
# Processing Record 10 of Set 3 | wonthaggi
# Processing Record 11 of Set 3 | punta arenas
# Processing Record 12 of Set 3 | mindelo
# Processing Record 13 of Set 3 | lokosovo
# Processing Record 14 of Set 3 | jermuk
# Processing Record 15 of Set 3 | linfen
# Processing Record 16 of Set 3 | shitkino
# Processing Record 17 of Set 3 | tuatapere
# Processing Record 18 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 19 of Set 3 | necochea
# Processing Record 20 of Set 3 | whitehorse
# Processing Record 21 of Set 3 | vardo
# Processing Record 22 of Set 3 | aklavik
# Processing Record 23 of Set 3 | nikolskoye
# Processing Record 24 of Set 3 | misawa
# Processing Record 25 of Set 3 | pangody
# Processing Record 26 of Set 3 | georgetown
# Processing Record 27 of Set 3 | beringovskiy
# Processing Record 28 of Set 3 | gimli
# Processing Record 29 of Set 3 | barrow
# Processing Record 30 of Set 3 | launceston
# Processing Record 31 of Set 3 | punta cardon
# Processing Record 32 of Set 3 | saraipali
# Processing Record 33 of Set 3 | vila velha
# Processing Record 34 of Set 3 | sao jose da coroa grande
# Processing Record 35 of Set 3 | tshikapa
# Processing Record 36 of Set 3 | malanje
# Processing Record 37 of Set 3 | tasiilaq
# Processing Record 38 of Set 3 | tagusao
# Processing Record 39 of Set 3 | chengde
# Processing Record 40 of Set 3 | deputatskiy
# Processing Record 41 of Set 3 | concepcion del oro
# Processing Record 42 of Set 3 | ancud
# Processing Record 43 of Set 3 | dekoa
# City not found. Skipping...
# Processing Record 44 of Set 3 | scottsbluff
# Processing Record 45 of Set 3 | ikom
# Processing Record 46 of Set 3 | puerto ayora
# Processing Record 47 of Set 3 | pak phanang
# Processing Record 48 of Set 3 | torbay
# Processing Record 49 of Set 3 | thinadhoo
# Processing Record 50 of Set 3 | caravelas
# Processing Record 1 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 4 | cabo san lucas
# Processing Record 3 of Set 4 | kununurra
# Processing Record 4 of Set 4 | ivanjica
# Processing Record 5 of Set 4 | port alfred
# Processing Record 6 of Set 4 | florianopolis
# Processing Record 7 of Set 4 | srednekolymsk
# Processing Record 8 of Set 4 | upington
# Processing Record 9 of Set 4 | dikson
# Processing Record 10 of Set 4 | saint-philippe
# Processing Record 11 of Set 4 | victoria
# Processing Record 12 of Set 4 | borama
# City not found. Skipping...
# Processing Record 13 of Set 4 | inta
# Processing Record 14 of Set 4 | saint-ambroise
# Processing Record 15 of Set 4 | shahrud
# Processing Record 16 of Set 4 | binalbagan
# Processing Record 17 of Set 4 | lagunas
# Processing Record 18 of Set 4 | ust-ishim
# Processing Record 19 of Set 4 | arraias
# Processing Record 20 of Set 4 | chokurdakh
# Processing Record 21 of Set 4 | taksimo
# Processing Record 22 of Set 4 | nouakchott
# Processing Record 23 of Set 4 | yambio
# Processing Record 24 of Set 4 | vanimo
# Processing Record 25 of Set 4 | norman wells
# Processing Record 26 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 4 | dolni bousov
# Processing Record 28 of Set 4 | manyava
# Processing Record 29 of Set 4 | saint anthony
# Processing Record 30 of Set 4 | morros
# Processing Record 31 of Set 4 | eyl
# Processing Record 32 of Set 4 | maraa
# Processing Record 33 of Set 4 | guerrero negro
# Processing Record 34 of Set 4 | coahuayana
# Processing Record 35 of Set 4 | santa rosa
# Processing Record 36 of Set 4 | sao joao da barra
# Processing Record 37 of Set 4 | gallup
# Processing Record 38 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 39 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 4 | uga
# Processing Record 41 of Set 4 | vila
# Processing Record 42 of Set 4 | ahipara
# Processing Record 43 of Set 4 | tokmak
# Processing Record 44 of Set 4 | ornskoldsvik
# Processing Record 45 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 46 of Set 4 | lompoc
# Processing Record 47 of Set 4 | bambous virieux
# Processing Record 48 of Set 4 | hofn
# Processing Record 49 of Set 4 | honiara
# Processing Record 50 of Set 4 | huarmey
# Processing Record 1 of Set 5 | nishihara
# Processing Record 2 of Set 5 | orocue
# Processing Record 3 of Set 5 | atar
# Processing Record 4 of Set 5 | sao filipe
# Processing Record 5 of Set 5 | kamisu
# Processing Record 6 of Set 5 | ambilobe
# Processing Record 7 of Set 5 | arlit
# Processing Record 8 of Set 5 | gerash
# Processing Record 9 of Set 5 | saint george
# Processing Record 10 of Set 5 | olafsvik
# Processing Record 11 of Set 5 | chernyshevskiy
# Processing Record 12 of Set 5 | basco
# Processing Record 13 of Set 5 | cherskiy
# Processing Record 14 of Set 5 | betlitsa
# Processing Record 15 of Set 5 | kjollefjord
# Processing Record 16 of Set 5 | jieshi
# Processing Record 17 of Set 5 | kirakira
# Processing Record 18 of Set 5 | moorhead
# Processing Record 19 of Set 5 | auki
# Processing Record 20 of Set 5 | akyab
# Processing Record 21 of Set 5 | chuy
# Processing Record 22 of Set 5 | gartringen
# Processing Record 23 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 5 | pimentel
# Processing Record 25 of Set 5 | san patricio
# Processing Record 26 of Set 5 | wenatchee
# Processing Record 27 of Set 5 | lavrentiya
# Processing Record 28 of Set 5 | coquimbo
# Processing Record 29 of Set 5 | talisay
# Processing Record 30 of Set 5 | roswell
# Processing Record 31 of Set 5 | novosheshminsk
# Processing Record 32 of Set 5 | dianopolis
# City not found. Skipping...
# Processing Record 33 of Set 5 | acapulco
# Processing Record 34 of Set 5 | tiarei
# Processing Record 35 of Set 5 | camapua
# Processing Record 36 of Set 5 | los palacios
# Processing Record 37 of Set 5 | talnakh
# Processing Record 38 of Set 5 | leningradskiy
# Processing Record 39 of Set 5 | east london
# Processing Record 40 of Set 5 | usinsk
# Processing Record 41 of Set 5 | port macquarie
# Processing Record 42 of Set 5 | strezhevoy
# Processing Record 43 of Set 5 | imbituba
# Processing Record 44 of Set 5 | pendleton
# Processing Record 45 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 5 | constitucion
# Processing Record 47 of Set 5 | zyryanka
# Processing Record 48 of Set 5 | astipalaia
# City not found. Skipping...
# Processing Record 49 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 50 of Set 5 | adre
# Processing Record 1 of Set 6 | hasaki
# Processing Record 2 of Set 6 | tura
# Processing Record 3 of Set 6 | wamba
# Processing Record 4 of Set 6 | hamilton
# Processing Record 5 of Set 6 | esperance
# Processing Record 6 of Set 6 | codrington
# Processing Record 7 of Set 6 | lorengau
# Processing Record 8 of Set 6 | vila do maio
# Processing Record 9 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 6 | muros
# Processing Record 11 of Set 6 | tecpan
# Processing Record 12 of Set 6 | sept-iles
# Processing Record 13 of Set 6 | airai
# Processing Record 14 of Set 6 | fairbanks
# Processing Record 15 of Set 6 | itarema
# Processing Record 16 of Set 6 | sorland
# Processing Record 17 of Set 6 | matagami
# Processing Record 18 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 19 of Set 6 | paita
# Processing Record 20 of Set 6 | khandyga
# Processing Record 21 of Set 6 | ondjiva
# Processing Record 22 of Set 6 | isangel
# Processing Record 23 of Set 6 | ostrovnoy
# Processing Record 24 of Set 6 | cidreira
# Processing Record 25 of Set 6 | boende
# Processing Record 26 of Set 6 | bantogon
# Processing Record 27 of Set 6 | sistranda
# Processing Record 28 of Set 6 | tromso
# Processing Record 29 of Set 6 | los llanos de aridane
# Processing Record 30 of Set 6 | namatanai
# Processing Record 31 of Set 6 | batabano
# Processing Record 32 of Set 6 | bonaventure
# Processing Record 33 of Set 6 | snyder
# Processing Record 34 of Set 6 | invermere
# Processing Record 35 of Set 6 | inhambane
# Processing Record 36 of Set 6 | narsaq
# Processing Record 37 of Set 6 | acin
# City not found. Skipping...
# Processing Record 38 of Set 6 | klishkivtsi
# Processing Record 39 of Set 6 | rovenki
# Processing Record 40 of Set 6 | santa rosalia
# Processing Record 41 of Set 6 | shenjiamen
# Processing Record 42 of Set 6 | dourbali
# Processing Record 43 of Set 6 | nizhnyaya tavda
# Processing Record 44 of Set 6 | makurdi
# Processing Record 45 of Set 6 | mehamn
# Processing Record 46 of Set 6 | lebu
# Processing Record 47 of Set 6 | sobolevo
# Processing Record 48 of Set 6 | fallingbostel
# Processing Record 49 of Set 6 | salina cruz
# Processing Record 50 of Set 6 | la primavera
# Processing Record 1 of Set 7 | geraldton
# Processing Record 2 of Set 7 | qaqortoq
# Processing Record 3 of Set 7 | saint pete beach
# Processing Record 4 of Set 7 | abaza
# Processing Record 5 of Set 7 | nizwa
# Processing Record 6 of Set 7 | kimbe
# Processing Record 7 of Set 7 | ginir
# Processing Record 8 of Set 7 | mount gambier
# Processing Record 9 of Set 7 | mikuni
# Processing Record 10 of Set 7 | kampene
# Processing Record 11 of Set 7 | byron bay
# Processing Record 12 of Set 7 | katsuura
# Processing Record 13 of Set 7 | tarpon springs
# Processing Record 14 of Set 7 | maua
# Processing Record 15 of Set 7 | marsaxlokk
# Processing Record 16 of Set 7 | tautira
# Processing Record 17 of Set 7 | komsomolskiy
# Processing Record 18 of Set 7 | bandar-e lengeh
# Processing Record 19 of Set 7 | broome
# Processing Record 20 of Set 7 | arman
# Processing Record 21 of Set 7 | dorchester
# Processing Record 22 of Set 7 | pathanamthitta
# Processing Record 23 of Set 7 | bengkulu
# Processing Record 24 of Set 7 | nanortalik
# Processing Record 25 of Set 7 | madang
# Processing Record 26 of Set 7 | kaya
# Processing Record 27 of Set 7 | hovd
# Processing Record 28 of Set 7 | lewisporte
# Processing Record 29 of Set 7 | vostok
# Processing Record 30 of Set 7 | uong bi
# Processing Record 31 of Set 7 | menongue
# Processing Record 32 of Set 7 | bilma
# Processing Record 33 of Set 7 | klaksvik
# Processing Record 34 of Set 7 | rocha
# Processing Record 35 of Set 7 | kenai
# Processing Record 36 of Set 7 | prokuplje
# Processing Record 37 of Set 7 | celestun
# Processing Record 38 of Set 7 | taoudenni
# Processing Record 39 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 40 of Set 7 | worcester
# Processing Record 41 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 7 | karaton
# Processing Record 43 of Set 7 | dicabisagan
# Processing Record 44 of Set 7 | yangcun
# Processing Record 45 of Set 7 | parabel
# Processing Record 46 of Set 7 | kahului
# Processing Record 47 of Set 7 | alice springs
# Processing Record 48 of Set 7 | richards bay
# Processing Record 49 of Set 7 | the valley
# Processing Record 50 of Set 7 | souillac
# Processing Record 1 of Set 8 | pomabamba
# Processing Record 2 of Set 8 | marzuq
# Processing Record 3 of Set 8 | puerto escondido
# Processing Record 4 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 8 | andenes
# Processing Record 6 of Set 8 | masunga
# Processing Record 7 of Set 8 | kovur
# Processing Record 8 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 9 of Set 8 | lazaro cardenas
# Processing Record 10 of Set 8 | port blair
# Processing Record 11 of Set 8 | gizo
# Processing Record 12 of Set 8 | paoua
# Processing Record 13 of Set 8 | edd
# Processing Record 14 of Set 8 | kloulklubed
# Processing Record 15 of Set 8 | ballitoville
# Processing Record 16 of Set 8 | rio gallegos
# Processing Record 17 of Set 8 | grindavik
# Processing Record 18 of Set 8 | omboue
# Processing Record 19 of Set 8 | kasangulu
# Processing Record 20 of Set 8 | shangqiu
# Processing Record 21 of Set 8 | kumluca
# Processing Record 22 of Set 8 | irbeyskoye
# Processing Record 23 of Set 8 | burica
# City not found. Skipping...
# Processing Record 24 of Set 8 | ergani
# Processing Record 25 of Set 8 | saint-pierre
# Processing Record 26 of Set 8 | wuwei
# Processing Record 27 of Set 8 | sfantu gheorghe
# Processing Record 28 of Set 8 | pemangkat
# Processing Record 29 of Set 8 | ostersund
# Processing Record 30 of Set 8 | petukhovo
# Processing Record 31 of Set 8 | belmonte
# Processing Record 32 of Set 8 | portland
# Processing Record 33 of Set 8 | adrar
# Processing Record 34 of Set 8 | am timan
# Processing Record 35 of Set 8 | okha
# Processing Record 36 of Set 8 | santa ana
# Processing Record 37 of Set 8 | amreli
# Processing Record 38 of Set 8 | jaroslaw
# Processing Record 39 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 8 | yulara
# Processing Record 41 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 42 of Set 8 | hambantota
# Processing Record 43 of Set 8 | vanavara
# Processing Record 44 of Set 8 | villarrica
# Processing Record 45 of Set 8 | athenry
# Processing Record 46 of Set 8 | valparaiso
# Processing Record 47 of Set 8 | athabasca
# Processing Record 48 of Set 8 | ust-tsilma
# Processing Record 49 of Set 8 | diban
# Processing Record 50 of Set 8 | antalya
# Processing Record 1 of Set 9 | huilong
# Processing Record 2 of Set 9 | tabou
# Processing Record 3 of Set 9 | katobu
# Processing Record 4 of Set 9 | evensk
# Processing Record 5 of Set 9 | keetmanshoop
# Processing Record 6 of Set 9 | terney
# Processing Record 7 of Set 9 | kedrovka
# Processing Record 8 of Set 9 | yaan
# Processing Record 9 of Set 9 | anar darreh
# City not found. Skipping...
# Processing Record 10 of Set 9 | cockburn town
# Processing Record 11 of Set 9 | hokitika
# Processing Record 12 of Set 9 | rexburg
# Processing Record 13 of Set 9 | parsabad
# Processing Record 14 of Set 9 | camacha
# Processing Record 15 of Set 9 | oktyabrskoye
# Processing Record 16 of Set 9 | luau
# Processing Record 17 of Set 9 | kwinana
# Processing Record 18 of Set 9 | boksitogorsk
# Processing Record 19 of Set 9 | muzhi
# Processing Record 20 of Set 9 | puerto narino
# Processing Record 21 of Set 9 | himora
# City not found. Skipping...
# Processing Record 22 of Set 9 | vinh
# Processing Record 23 of Set 9 | kisesa
# Processing Record 24 of Set 9 | constancia
# Processing Record 25 of Set 9 | san cristobal
# Processing Record 26 of Set 9 | imeni babushkina
# Processing Record 27 of Set 9 | manutuke
# Processing Record 28 of Set 9 | bubaque
# Processing Record 29 of Set 9 | bjornevatn
# Processing Record 30 of Set 9 | marienburg
# Processing Record 31 of Set 9 | saint-augustin
# Processing Record 32 of Set 9 | hagere hiywet
# Processing Record 33 of Set 9 | tuktoyaktuk
# Processing Record 34 of Set 9 | ilulissat
# Processing Record 35 of Set 9 | clyde river
# Processing Record 36 of Set 9 | zolotukhino
# Processing Record 37 of Set 9 | half moon bay
# Processing Record 38 of Set 9 | afmadu
# City not found. Skipping...
# Processing Record 39 of Set 9 | tiksi
# Processing Record 40 of Set 9 | russell
# Processing Record 41 of Set 9 | dudinka
# Processing Record 42 of Set 9 | ewa beach
# Processing Record 43 of Set 9 | olinda
# Processing Record 44 of Set 9 | bukan
# Processing Record 45 of Set 9 | marawi
# Processing Record 46 of Set 9 | nemuro
# Processing Record 47 of Set 9 | akcakoca
# Processing Record 48 of Set 9 | buta
# Processing Record 49 of Set 9 | senneterre
# Processing Record 50 of Set 9 | quang ngai
# Processing Record 1 of Set 10 | ginda
# Processing Record 2 of Set 10 | kavieng
# Processing Record 3 of Set 10 | yamada
# Processing Record 4 of Set 10 | bougouni
# City not found. Skipping...
# Processing Record 5 of Set 10 | moindou
# Processing Record 6 of Set 10 | merta
# Processing Record 7 of Set 10 | dalvik
# Processing Record 8 of Set 10 | cairns
# Processing Record 9 of Set 10 | chirongui
# Processing Record 10 of Set 10 | takhatgarh
# Processing Record 11 of Set 10 | flinders
# Processing Record 12 of Set 10 | aquiraz
# Processing Record 13 of Set 10 | awbari
# Processing Record 14 of Set 10 | pathein
# Processing Record 15 of Set 10 | loanda
# Processing Record 16 of Set 10 | nelson bay
# Processing Record 17 of Set 10 | havelock
# Processing Record 18 of Set 10 | kudahuvadhoo
# Processing Record 19 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 10 | burgeo
# Processing Record 21 of Set 10 | vrises
# Processing Record 22 of Set 10 | hachinohe
# Processing Record 23 of Set 10 | kontagora
# Processing Record 24 of Set 10 | fengcheng
# Processing Record 25 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 10 | dandong
# Processing Record 27 of Set 10 | baoro
# Processing Record 28 of Set 10 | george town
# Processing Record 29 of Set 10 | dakar
# Processing Record 30 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 31 of Set 10 | waipawa
# Processing Record 32 of Set 10 | hobyo
# Processing Record 33 of Set 10 | tabukiniberu
# City not found. Skipping...
# Processing Record 34 of Set 10 | coihaique
# Processing Record 35 of Set 10 | waingapu
# Processing Record 36 of Set 10 | abengourou
# Processing Record 37 of Set 10 | namibe
# Processing Record 38 of Set 10 | mayya
# Processing Record 39 of Set 10 | envira
# Processing Record 40 of Set 10 | jinxiang
# Processing Record 41 of Set 10 | yantal
# Processing Record 42 of Set 10 | mangai
# Processing Record 43 of Set 10 | woodburn
# Processing Record 44 of Set 10 | lar
# Processing Record 45 of Set 10 | togur
# Processing Record 46 of Set 10 | colac
# Processing Record 47 of Set 10 | zhigansk
# Processing Record 48 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 49 of Set 10 | longkou
# Processing Record 50 of Set 10 | barra do corda
# Processing Record 1 of Set 11 | yeppoon
# Processing Record 2 of Set 11 | high level
# Processing Record 3 of Set 11 | maragogi
# Processing Record 4 of Set 11 | esperantina
# Processing Record 5 of Set 11 | san juan del rio
# Processing Record 6 of Set 11 | goalpara
# Processing Record 7 of Set 11 | pensacola
# Processing Record 8 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 9 of Set 11 | riyadh
# Processing Record 10 of Set 11 | aripuana
# Processing Record 11 of Set 11 | la ronge
# Processing Record 12 of Set 11 | utrecht
# Processing Record 13 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 11 | pleasanton
# Processing Record 15 of Set 11 | superior
# Processing Record 16 of Set 11 | havre-saint-pierre
# Processing Record 17 of Set 11 | san bartolome
# Processing Record 18 of Set 11 | kosh-agach
# Processing Record 19 of Set 11 | ayagoz
# Processing Record 20 of Set 11 | fortuna
# Processing Record 21 of Set 11 | mangrol
# Processing Record 22 of Set 11 | martapura
# Processing Record 23 of Set 11 | vryburg
# Processing Record 24 of Set 11 | langenburg
# Processing Record 25 of Set 11 | quatre cocos
# Processing Record 26 of Set 11 | druzhinino
# Processing Record 27 of Set 11 | bonthe
# Processing Record 28 of Set 11 | alamos
# Processing Record 29 of Set 11 | moree
# Processing Record 30 of Set 11 | sid
# Processing Record 31 of Set 11 | tingi
# Processing Record 32 of Set 11 | pandan
# Processing Record 33 of Set 11 | pires do rio
# Processing Record 34 of Set 11 | kharan
# Processing Record 35 of Set 11 | petrozavodsk
# Processing Record 36 of Set 11 | yerbogachen
# Processing Record 37 of Set 11 | hervey bay
# Processing Record 38 of Set 11 | dunedin
# Processing Record 39 of Set 11 | svetlogorsk
# Processing Record 40 of Set 11 | jasper
# Processing Record 41 of Set 11 | liwale
# Processing Record 42 of Set 11 | moerai
# Processing Record 43 of Set 11 | roma
# Processing Record 44 of Set 11 | kruisfontein
# City not found. Skipping...
# Processing Record 45 of Set 11 | rawson
# Processing Record 46 of Set 11 | korla
# Processing Record 47 of Set 11 | makushino
# Processing Record 48 of Set 11 | shumskiy
# Processing Record 49 of Set 11 | banda aceh
# Processing Record 50 of Set 11 | borlange
# City not found. Skipping...
# Processing Record 1 of Set 12 | henties bay
# Processing Record 2 of Set 12 | hammerfest
# Processing Record 3 of Set 12 | vernon
# Processing Record 4 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 12 | xining
# Processing Record 6 of Set 12 | trinidad
# Processing Record 7 of Set 12 | molteno
# Processing Record 8 of Set 12 | panaba
# Processing Record 9 of Set 12 | barabai
# Processing Record 10 of Set 12 | umm ruwabah
# City not found. Skipping...
# Processing Record 11 of Set 12 | lincoln
# Processing Record 12 of Set 12 | bourges
# Processing Record 13 of Set 12 | karratha
# Processing Record 14 of Set 12 | rapid valley
# Processing Record 15 of Set 12 | aksarka
# Processing Record 16 of Set 12 | chiapa
# Processing Record 17 of Set 12 | taltal
# Processing Record 18 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 12 | verkhnevilyuysk
# Processing Record 20 of Set 12 | salalah
# Processing Record 21 of Set 12 | touros
# Processing Record 22 of Set 12 | lagoa
# Processing Record 23 of Set 12 | abu kamal
# Processing Record 24 of Set 12 | boromo
# Processing Record 25 of Set 12 | monteagudo
# Processing Record 26 of Set 12 | kutum
# Processing Record 27 of Set 12 | diu
# Processing Record 28 of Set 12 | potgietersrus
# City not found. Skipping...
# Processing Record 29 of Set 12 | tual
# Processing Record 30 of Set 12 | carauari
# Processing Record 31 of Set 12 | lovozero
# Processing Record 32 of Set 12 | sorong
# Processing Record 33 of Set 12 | darhan
# Processing Record 34 of Set 12 | sahuaripa
# Processing Record 35 of Set 12 | teeli
# Processing Record 36 of Set 12 | labuhan
# Processing Record 37 of Set 12 | shawville
# Processing Record 38 of Set 12 | tottori
# Processing Record 39 of Set 12 | yangjiang
# Processing Record 40 of Set 12 | kearney
# Processing Record 41 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 42 of Set 12 | nisia floresta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# format columns
city_data_df['Lat'] = city_data_df['Lat'].map('{:.2f}'.format)
city_data_df['Lng'] = city_data_df['Lng'].map('{:.2f}'.format)

# reorder columns
new_column_order = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0    Port Lincoln      AU  -34.73   135.87     50.99        80          57
# 1     Pangnirtung      CA   66.15   -65.71     50.00        81         100
# 2        Tessalit      ML   20.20     1.01     75.18        72          98
# 3         Rikitea      PF  -23.12  -134.97     73.36        75           0
# 4        Chunoyar      RU   57.45    97.32     52.61        97          81
# 5          Kodiak      US   57.79  -152.41     54.91        76           0
# 6  Severo-Kurilsk      RU   50.68   156.12     51.69        97         100
# 7    Podosinovets      RU   60.28    47.07     52.54        96          89
# 8   Mar Del Plata      AR  -38.00   -57.56     63.95        53           0
# 9     Grand Gaube      MU  -20.01    57.66     68.40        72          96
#
#    Wind Speed Current Description
# 0       10.20       broken clouds
# 1        8.05     overcast clouds
# 2       14.88       moderate rain
# 3        2.04           clear sky
# 4        3.65       broken clouds
# 5        5.75           clear sky
# 6       12.91     overcast clouds
# 7        3.71     overcast clouds
# 8       16.11           clear sky
# 9       15.99     overcast clouds

# %%
# create the output csv
output_data_file = "WeatherPy_Database.csv"

# export the city_data_df to the csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
